# %%
from torchvision.datasets import FashionMNIST
from torchvision import transforms

from utils.utils import train
from utils.tutorial1_learners import TargetPropLearner
from utils.tutorial1_learners import BaselineLearner1

# %% [markdown]
# # Steps
#
# 1) Create each layer (AutoencoderLearner)
# 2) Create the TargetPropLearner
# 3) Run the training on the baseline
# 4) Run the training on the target propagation learner

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))])

training_dataset = FashionMNIST(
    '../../Datasets/',
    transform=transform, download=True
)

learner = BaselineLearner1(
    784, 300, 300, 300, 10
)

train(learner, training_dataset, 100, device='cpu')
# Out:
# 100%|██████████| 469/469 [00:07<00:00, 65.49it/s, loss=0.629]
# 100%|██████████| 469/469 [00:07<00:00, 63.34it/s, loss=0.515]
#  66%|██████▌   | 309/469 [00:05<00:02, 61.49it/s, loss=0.484]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 14>()
#       5 training_dataset = FashionMNIST(
#       6     '../../Datasets/',
#       7     transform=transform, download=True
#       8 )
#      10 learner = BaselineLearner1(
#      11     784, 300, 300, 300, 10
#      12 )
# ---> 14 train(learner, training_dataset, 100, device='cpu')
#
# File ~/Development/zenkai_tutorials/tutorials/target_propagation/utils/utils.py:75, in train(learner, dataset, n_epochs, device)
#      72 x = x.to(device)
#      73 x1_t = x1_t.to(device)
# ---> 75 y = learner(x.view(x.shape[0], -1))
#      76 assessment = loss(y, x1_t)
#      77 assessment.backward()
#
# File /opt/miniconda3/envs/py310torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/miniconda3/envs/py310torch/lib/python3.10/site-packages/zenkai/kaku/_lm2.py:645, in LearningMachine.forward(self, *x, **kwargs)
#     639 def forward(
#     640     self, *x, **kwargs
#     641 ) -> IO:
#     642
#     643     # Have to flatten io to use with F
#     644     x = [x_i.requires_grad_(True) if isinstance(x_i, torch.Tensor) else x_i for x_i in x]
# --> 645     y = LearningF.apply(self, kwargs, *x)
#     646     return y
#
# File /opt/miniconda3/envs/py310torch/lib/python3.10/site-packages/zenkai/kaku/_lm2.py:464, in LearningF.forward(ctx, self, kwargs, *args)
#     461 x = IO(args).clone(True)
#     463 state = State()
# --> 464 y = self.forward_nn(x, state=state, **kwargs)
#     465 if isinstance(y, typing.Tuple):
#     466     y = IO(y)
#
# File /opt/miniconda3/envs/py310torch/lib/python3.10/site-packages/zenkai/kaku/_lm2.py:601, in LearningMachine._forward_hook_runner(self, x, state, *args, **kwargs)
#     595 def _forward_hook_runner(self, x: IO, state: State, *args, **kwargs):
#     596     """
#     597     Args:
#     598         x (IO): The input to the module
#     599         t (IO): The target
#     600     """
# --> 601     y = self._base_forward(x, state, *args, **kwargs)
#     602     for hook in self._y_hooks:
#     603         y = hook(self, x, y, state)
#
# File ~/Development/zenkai_tutorials/tutorials/target_propagation/utils/tutorial1_learners.py:172, in BaselineLearner1.forward_nn(self, x, state, batch_idx)
#     170 def forward_nn(self, x: IO, state: State, batch_idx: Idx = None) -> Tensor:
# --> 172     y = self.layer1(x.f)
#     173     y = self.layer2(y)
#     174     y = self.layer3(y)
#
# File /opt/miniconda3/envs/py310torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Development/zenkai_tutorials/tutorials/target_propagation/utils/utils.py:46, in Layer.forward(self, x)
#      44 def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 46     y = self.dropout(x)
#      47     y = self.linear(y)
#      48     y = self.norm(y)
#
# File /opt/miniconda3/envs/py310torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/miniconda3/envs/py310torch/lib/python3.10/site-packages/torch/nn/modules/dropout.py:58, in Dropout.forward(self, input)
#      57 def forward(self, input: Tensor) -> Tensor:
# ---> 58     return F.dropout(input, self.p, self.training, self.inplace)
#
# File /opt/miniconda3/envs/py310torch/lib/python3.10/site-packages/torch/nn/functional.py:1279, in dropout(input, p, training, inplace)
#    1277 if p < 0.0 or p > 1.0:
#    1278     raise ValueError("dropout probability has to be between 0 and 1, " "but got {}".format(p))
# -> 1279 return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#
# KeyboardInterrupt:

# %% [markdown]
# # TargetPropLearner

# %%
learner = TargetPropLearner(
    784, 300, 300, 300, 10
)


train(learner, training_dataset, 100, device='cpu')
